# %%
import pandas as pd

# %%
heart = pd.read_csv("./heart_X.csv")
heart = heart.drop("Unnamed: 0", axis=1)
heart.head()
# Out:
#    Age  Sex  cp  trestbps        chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   28    1   2     130.0  132.000000  0.0      2.0    185.0    0.0      0.0
# 1   29    1   2     120.0  243.000000  0.0      0.0    160.0    0.0      0.0
# 2   29    1   2     140.0  200.048724  0.0      0.0    170.0    0.0      0.0
# 3   30    0   1     170.0  237.000000  0.0      1.0    170.0    0.0      0.0
# 4   31    0   2     100.0  219.000000  0.0      1.0    150.0    0.0      0.0
#
#      Place
# 0  Hungary
# 1  Hungary
# 2  Hungary
# 3  Hungary
# 4  Hungary

# %%
heart["Sex"].replace(to_replace=1, value="male", inplace=True)
heart["Sex"].replace(to_replace=0, value="female", inplace=True)

# %%
heart.head()
# Out:
#    Age     Sex  cp  trestbps        chol  fbs  restecg  thalach  exang  \
# 0   28    male   2     130.0  132.000000  0.0      2.0    185.0    0.0
# 1   29    male   2     120.0  243.000000  0.0      0.0    160.0    0.0
# 2   29    male   2     140.0  200.048724  0.0      0.0    170.0    0.0
# 3   30  female   1     170.0  237.000000  0.0      1.0    170.0    0.0
# 4   31  female   2     100.0  219.000000  0.0      1.0    150.0    0.0
#
#    oldpeak    Place
# 0      0.0  Hungary
# 1      0.0  Hungary
# 2      0.0  Hungary
# 3      0.0  Hungary
# 4      0.0  Hungary

# %%
heart["cp"].replace(to_replace=1, value="type_1", inplace=True)
heart["cp"].replace(to_replace=2, value="type_2", inplace=True)
heart["cp"].replace(to_replace=3, value="type_3", inplace=True)
heart["cp"].replace(to_replace=4, value="type_4", inplace=True)

# %%
heart.head()
# Out:
#    Age     Sex      cp  trestbps        chol  fbs  restecg  thalach  exang  \
# 0   28    male  type_2     130.0  132.000000  0.0      2.0    185.0    0.0
# 1   29    male  type_2     120.0  243.000000  0.0      0.0    160.0    0.0
# 2   29    male  type_2     140.0  200.048724  0.0      0.0    170.0    0.0
# 3   30  female  type_1     170.0  237.000000  0.0      1.0    170.0    0.0
# 4   31  female  type_2     100.0  219.000000  0.0      1.0    150.0    0.0
#
#    oldpeak    Place
# 0      0.0  Hungary
# 1      0.0  Hungary
# 2      0.0  Hungary
# 3      0.0  Hungary
# 4      0.0  Hungary

# %%
heart.to_csv("./heart_X.csv")

# %%
churn = pd.read_csv("./churn_X.csv")
churn = churn.drop("Unnamed: 0", axis=1)
churn.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
churn['HasCrCard'].replace(to_replace=1, value="yes", inplace=True)
churn['HasCrCard'].replace(to_replace=0, value="no", inplace=True)

churn["IsActiveMember"].replace(to_replace=1, value="yes", inplace=True)
churn["IsActiveMember"].replace(to_replace=0, value="no", inplace=True)

# %%
churn.to_csv("./churn_X.csv")
